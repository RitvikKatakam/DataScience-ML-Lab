# %%
#stack
def reverse_string(text):
    stack_homework = []
    #push
    for ch in text:
        stack_homework.append(ch)
    
    reversed_str = ""
    
    #pop
    while stack_homework:
        reversed_str += stack_homework.pop()
    
    return reversed_str

# %%
reverse_string("hello")
# Out:
# 'olleh'
