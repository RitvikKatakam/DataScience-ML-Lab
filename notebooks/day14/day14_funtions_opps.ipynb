# %% [markdown]
# ##Functions

# %%
def function_name(parameters):
  return value

# %% [markdown]
# they are builtin python functions, such as:
# * print()
# * len()
# * type()
# * range()

# %%
import imported_math_operation_s

# %%
imported_math_operation_s.add(5,5)
# Out:
# 10

# %%
imported_math_operation_s.multiply(5,5)
# Out:
# 25

# %%
from imported_math_operation_s import divide

# %% [markdown]
# only we can use divide operation

# %%
imported_math_operation_s.divide(3,3)
# Out:
# 1.0

# %% [markdown]
# but cannot use other functions

# %%
imported_math_operation_s.subtract(3,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_503/2868938887.py in <cell line: 0>()
# ----> 1 imported_math_operation_s.subtract(3,1)
#
# AttributeError: module 'imported_math_operation_s' has no attribute 'subtract'
