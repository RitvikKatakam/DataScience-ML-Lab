# %% [markdown]
# Stack
#
# -push
#
# -pop
#
# -peek

# %% [markdown]
# stack follows LIFO

# %%
Stack_practice = []

# %%
Stack_practice.append('first item')

# %%
Stack_practice.append('second item')

# %%
Stack_practice.append('third item')

# %%
print(Stack_practice)
# Out:
# ['first item', 'second item', 'third item']

# %%
Stack_practice[1]
# Out:
# 'second item'

# %%
lenghth_of_stack = len(Stack_practice)
lenghth_of_stack
# Out:
# 3

# %%
Stack_practice.pop()
# Out:
# 'third item'

# %%
if len(Stack_practice) > 0:
    print("Top element is:", Stack_practice[-1])  # Peek
else:
    print("Stack is empty")
# Out:
# Top element is: second item

# %% [markdown]
# queue
#
# first in first out

# %%
#example - people waiting in a ticket counter line

# %%
from collections import deque

# %%
queue_practice = deque()

# %%
queue_practice.append('first item')

# %%
queue_practice.append('second item')

# %%
queue_practice.append('third item')

# %%
print('queue:',queue_practice)
# Out:
# queue: deque(['first item', 'second item', 'third item'])

# %%
#deque elements from queue in FIFO order and prefered way (without thread safety)

queue_practice.popleft()
# Out:
# 'first item'

# %%
print(queue_practice)
# Out:
# deque(['second item', 'third item'])

# %%
#thread safety can be achived using queue module. queue module has 2 meathods
#put() used to add an element
#get() used to remove an element

# %%
import queue
queue_with_thread_safety = queue.Queue()

# %%
queue_with_thread_safety.put('job A')

# %%
queue_with_thread_safety.put('job B')

# %%
queue_with_thread_safety.put('job C')

# %%
print(queue_with_thread_safety)

# %%
queue_with_thread_safety.get()
# Out:
# 'job A'

# %%
queue_with_thread_safety.get()
# Out:
# 'job B'
