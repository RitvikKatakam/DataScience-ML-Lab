# %% [markdown]
# operations are symbol that performs operations on variable or values
#
# * arthematic
# * compariison
# * logical
# * assignments

# %%
#addition,subraction,multiplication,division,modulus,power,floor division
40**4
# Out:
# 2560000

# %%
40*40*40*40
# Out:
# 2560000

# %%
#floor division
14//4
# Out:
# 3

# %%
14/4
# Out:
# 3.5

# %%
# == means equal , != means not eal , <  , > , <= , >= greter than equal
3<5
# Out:
# True

# %%
3>2
# Out:
# True

# %%
3>3
# Out:
# False

# %%
3>=3
# Out:
# True

# %%
#logical
#and, or ,not
a=5
b=10
print(b>5 and a<10)
print(b<5 or a<10)
print(not(b>a))
# Out:
# True
# True
# False

# %%
#assignment operators
#5 operators
a=5
print(a)
a+=2
# Out:
# 5

# %%
print(a)
# Out:
# 7

# %%
a+=3
print(a)
# Out:
# 10

# %%
b=5
print(b)
b-=1
print(b)
# Out:
# 5
# 4

# %%
c=3
print(c)
c*=5
print(c)
# Out:
# 3
# 15

# %%
d=8
print(d)
d/=2
print(d)
# Out:
# 8
# 4.0

# %%
#expression
a=10+2-1*3
a
# Out:
# 9

# %% [markdown]
# B – Brackets ()
#
# O – Orders (powers/exponents **)
#
# D – Division / or //
#
# M – Multiplication *
#
# A – Addition +
#
# S – Subtraction -

# %%
a=(5+3)*2
a
# Out:
# 16

# %%
a=5+3*2
a
# Out:
# 11
