# %% [markdown]
# #inheritance
# Inheritance means one class can inherit properties and methods from another class.

# %%
from abc import ABC,abstractmethod  #parent class
class Shape:
  def description(self):
    print("this is the base class")

# %%
class Circle(Shape):     #shape is my parent,base class and circle is my child class
  def __init__(self,radius):
    self.radius=radius

  def calculateArea(self):
    pi=3.14
    return pi*(self.radius**2)

circle1=Circle(5)
circle1.description()

circle1.calculateArea()
# Out:
# this is the base class
# 78.5

# %% [markdown]
# # Abstraction
# * Abstraction means hiding complex implementation details and showing only the necessary features.
# * Users interact with simple interfaces without knowing internal logic.

# %%
from abc import ABC,abstractmethod
class Vehicle(ABC):

  @abstractmethod
  def start(self):
    pass

  # declartion means only declaring functions without logic
  # defination means writing the logic inside the function


class Car(Vehicle):

  def __init__(self):
    print("this is cars constructor")

  def start(self):
    print("the car start with the key")

car1=Car()

car1.start()
# Out:
# this is cars constructor
# the car start with the key

# %% [markdown]
# # Polymorphism
# polmorphism means one name different forms
#
# * method overriding

# %%
# polymorphism withmethod Overriding
class Animal:
    def sound(self):
        print("Animal makes sound")


class Dog(Animal):
    def sound(self):
        print("Dog barks")


class Cat(Animal):
    def sound(self):
        print("Cat meows")


a = Animal()
d = Dog()
c = Cat()

a.sound()
d.sound()
c.sound()
# Out:
# Animal makes sound
# Dog barks
# Cat meows

# %% [markdown]
# * polymorphism with different class or DuckTyping
#  -Different classes implement the same method name, even without inheritance.

# %%
# polymorphism with different classes or DuckTyping (without Inheritace)

class Dog:
    def speak(self):
        print("Bark")


class Cat:
    def speak(self):
        print("Meow")


class Bird:
    def speak(self):
        print("Chirp")


animals = [Dog(), Cat(), Bird()]

for animal in animals:
    animal.speak()
# Out:
# Bark
# Meow
# Chirp

# %%
#super class

class Person:
    def __init__(self, name):
        self.name = name
        print("Person constructor called")

    def display(self):
      print("the name of the person is:",self.name)


class Student(Person):
    def __init__(self, name, grade):
        super().__init__(name)   # calling parent constructor
        super().display()
        self.grade = grade
        print("Student constructor called")




s = Student("Rahul", "A")
# Out:
# Person constructor called
# the name of the person is: Rahul
# Student constructor called
